# %% [markdown]
# ## Import Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %%
df = pd.read_csv('E:/Data Analyst Portofilio Data/Datasets/Netflex/disney_plus_titles.csv')
df
# Out:
#      show_id     type                                             title  \
# 0         s1    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1         s2    Movie                            Ernest Saves Christmas
# 2         s3    Movie                      Ice Age: A Mammoth Christmas
# 3         s4    Movie                        The Queen Family Singalong
# 4         s5  TV Show                             The Beatles: Get Back
# ...      ...      ...                                               ...
# 1445   s1446    Movie                          X-Men Origins: Wolverine
# 1446   s1447    Movie    Night at the Museum: Battle of the Smithsonian
# 1447   s1448    Movie                                   Eddie the Eagle
# 1448   s1449    Movie                              Bend It Like Beckham
# 1449   s1450    Movie             Captain Sparky vs. The Flying Saucers
#
#                                director  \
# 0     Alonso Ramirez Ramos, Dave Wasson
# 1                           John Cherry
# 2                          Karen Disher
# 3                       Hamish Hamilton
# 4                                   NaN
# ...                                 ...
# 1445                         Gavin Hood
# 1446                         Shawn Levy
# 1447                    Dexter Fletcher
# 1448                    Gurinder Chadha
# 1449                        Mark Waring
#
#                                                    cast  \
# 0     Chris Diamantopoulos, Tony Anselmo, Tress MacN...
# 1              Jim Varney, Noelle Parker, Douglas Seale
# 2     Raymond Albert Romano, John Leguizamo, Denis L...
# 3     Darren Criss, Adam Lambert, Derek Hough, Alexa...
# 4     John Lennon, Paul McCartney, George Harrison, ...
# ...                                                 ...
# 1445  Hugh Jackman, Liev Schreiber, Danny Huston, wi...
# 1446  Ben Stiller, Amy Adams, Owen Wilson, Hank Azar...
# 1447  Tom Costello, Jo Hartley, Keith Allen, Dickon ...
# 1448  Parminder Nagra, Keira Knightley, Jonathan Rhy...
# 1449                                      Charlie Tahan
#
#                                      country          date_added  \
# 0                                        NaN   November 26, 2021
# 1                                        NaN   November 26, 2021
# 2                              United States   November 26, 2021
# 3                                        NaN   November 26, 2021
# 4                                        NaN   November 25, 2021
# ...                                      ...                 ...
# 1445           United States, United Kingdom        June 4, 2021
# 1446                   United States, Canada       April 2, 2021
# 1447  United Kingdom, Germany, United States   December 18, 2020
# 1448  United Kingdom, Germany, United States  September 18, 2020
# 1449                           United States       April 1, 2020
#
#       release_year rating  duration  \
# 0             2016   TV-G    23 min
# 1             1988     PG    91 min
# 2             2011   TV-G    23 min
# 3             2021  TV-PG    41 min
# 4             2021    NaN  1 Season
# ...            ...    ...       ...
# 1445          2009  PG-13   108 min
# 1446          2009     PG   106 min
# 1447          2016  PG-13   107 min
# 1448          2003  PG-13   112 min
# 1449          2012   TV-G     2 min
#
#                                           listed_in  \
# 0                                 Animation, Family
# 1                                            Comedy
# 2                         Animation, Comedy, Family
# 3                                           Musical
# 4                     Docuseries, Historical, Music
# ...                                             ...
# 1445      Action-Adventure, Family, Science Fiction
# 1446               Action-Adventure, Comedy, Family
# 1447                    Biographical, Comedy, Drama
# 1448                   Buddy, Comedy, Coming of Age
# 1449  Action-Adventure, Animals & Nature, Animation
#
#                                             description
# 0      Join Mickey and the gang as they duck the halls!
# 1     Santa Claus passes his magic bag to a new St. ...
# 2             Sid the Sloth is on Santa's naughty list.
# 3                  This is real life, not just fantasy!
# 4     A three-part documentary from Peter Jackson ca...
# ...                                                 ...
# 1445  Wolverine unites with legendary X-Men to fight...
# 1446  Larry Daley returns to rescue some old friends...
# 1447  True story of Eddie Edwards, a British ski-jum...
# 1448  Despite the wishes of their traditional famili...
# 1449         View one of Sparky's favorite home movies.
#
# [1450 rows x 12 columns]

# %% [markdown]
# ## Data Preprocessing

# %%
df.head()
# Out:
#   show_id     type                                             title  \
# 0      s1    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1      s2    Movie                            Ernest Saves Christmas
# 2      s3    Movie                      Ice Age: A Mammoth Christmas
# 3      s4    Movie                        The Queen Family Singalong
# 4      s5  TV Show                             The Beatles: Get Back
#
#                             director  \
# 0  Alonso Ramirez Ramos, Dave Wasson
# 1                        John Cherry
# 2                       Karen Disher
# 3                    Hamish Hamilton
# 4                                NaN
#
#                                                 cast        country  \
# 0  Chris Diamantopoulos, Tony Anselmo, Tress MacN...            NaN
# 1           Jim Varney, Noelle Parker, Douglas Seale            NaN
# 2  Raymond Albert Romano, John Leguizamo, Denis L...  United States
# 3  Darren Criss, Adam Lambert, Derek Hough, Alexa...            NaN
# 4  John Lennon, Paul McCartney, George Harrison, ...            NaN
#
#           date_added  release_year rating  duration  \
# 0  November 26, 2021          2016   TV-G    23 min
# 1  November 26, 2021          1988     PG    91 min
# 2  November 26, 2021          2011   TV-G    23 min
# 3  November 26, 2021          2021  TV-PG    41 min
# 4  November 25, 2021          2021    NaN  1 Season
#
#                        listed_in  \
# 0              Animation, Family
# 1                         Comedy
# 2      Animation, Comedy, Family
# 3                        Musical
# 4  Docuseries, Historical, Music
#
#                                          description
# 0   Join Mickey and the gang as they duck the halls!
# 1  Santa Claus passes his magic bag to a new St. ...
# 2          Sid the Sloth is on Santa's naughty list.
# 3               This is real life, not just fantasy!
# 4  A three-part documentary from Peter Jackson ca...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1450 entries, 0 to 1449
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       1450 non-null   object
#  1   type          1450 non-null   object
#  2   title         1450 non-null   object
#  3   director      977 non-null    object
#  4   cast          1260 non-null   object
#  5   country       1231 non-null   object
#  6   date_added    1447 non-null   object
#  7   release_year  1450 non-null   int64
#  8   rating        1447 non-null   object
#  9   duration      1450 non-null   object
#  10  listed_in     1450 non-null   object
#  11  description   1450 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 136.1+ KB

# %%
# Convert data type for date_added colum to datetime
df["date_added"] = pd.to_datetime(df['date_added'])

# Add new columns
df['year_added'] = df['date_added'].dt.year
df['month_added'] = df['date_added'].dt.month
df['day_added'] = df['date_added'].dt.day

# %%
# check null values
df.isnull().sum()
# Out:
# show_id           0
# type              0
# title             0
# director        473
# cast            190
# country         219
# date_added        3
# release_year      0
# rating            3
# duration          0
# listed_in         0
# description       0
# year_added        3
# month_added       3
# day_added         3
# dtype: int64

# %%
# drop  unnecessary features/columns

# drop column description
df.drop('show_id',axis=1,inplace=True)

# drop column director
df.drop('director',axis=1,inplace=True)

# drop column cast
df.drop('cast',axis=1,inplace=True)

# drop column description
df.drop('description',axis=1,inplace=True)

# %%
# the mode value of country column
df['country'].value_counts().idxmax()
# Out:
# 'United States'

# %%
# the mode value of rating column
df['rating'].value_counts().idxmax()
# Out:
# 'TV-G'

# %%
# Replacing null values by the mode of column

df['country'].replace(np.nan,'United States',inplace=True)

df['rating'].replace(np.nan,'TV-MA',inplace=True)

# drop the null values for rest columns

df.dropna(inplace=True)

# %%
# check null values
df.isnull().sum()
# Out:
# type            0
# title           0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# year_added      0
# month_added     0
# day_added       0
# dtype: int64

# %%
# check duplicated values
df.duplicated().value_counts()
# Out:
# False    1447
# dtype: int64

# %%
df.head()
# Out:
#       type                                             title        country  \
# 0    Movie  Duck the Halls: A Mickey Mouse Christmas Special  United States
# 1    Movie                            Ernest Saves Christmas  United States
# 2    Movie                      Ice Age: A Mammoth Christmas  United States
# 3    Movie                        The Queen Family Singalong  United States
# 4  TV Show                             The Beatles: Get Back  United States
#
#   date_added  release_year rating  duration                      listed_in  \
# 0 2021-11-26          2016   TV-G    23 min              Animation, Family
# 1 2021-11-26          1988     PG    91 min                         Comedy
# 2 2021-11-26          2011   TV-G    23 min      Animation, Comedy, Family
# 3 2021-11-26          2021  TV-PG    41 min                        Musical
# 4 2021-11-25          2021  TV-MA  1 Season  Docuseries, Historical, Music
#
#    year_added  month_added  day_added
# 0      2021.0         11.0       26.0
# 1      2021.0         11.0       26.0
# 2      2021.0         11.0       26.0
# 3      2021.0         11.0       26.0
# 4      2021.0         11.0       25.0

# %%
df[['year_added','month_added','day_added']] = df[['year_added','month_added','day_added']].astype('int')

# %%
# Calculate summary statistics for categorical columns
df.describe(include='object')
# Out:
#          type                                             title  \
# count    1447                                              1447
# unique      2                                              1447
# top     Movie  Duck the Halls: A Mickey Mouse Christmas Special
# freq     1052                                                 1
#
#               country rating  duration                  listed_in
# count            1447   1447      1447                       1447
# unique             89     10       158                        329
# top     United States   TV-G  1 Season  Animation, Comedy, Family
# freq             1222    318       219                        124

# %%
df['type'].value_counts()
# Out:
# Movie      1052
# TV Show     395
# Name: type, dtype: int64

# %%
df['country'].value_counts()
# Out:
# United States                                                  1222
# United States, Canada                                            30
# United Kingdom                                                   23
# United States, United Kingdom                                    22
# Canada, United States                                            17
#                                                                ...
# Ireland, United States                                            1
# Ireland, United Kingdom, United States, South Korea, Canada       1
# United States, South Korea, France                                1
# United States, Australia, France, Canada                          1
# United States, Ireland                                            1
# Name: country, Length: 89, dtype: int64

# %%
df['rating'].value_counts()
# Out:
# TV-G        318
# TV-PG       301
# G           253
# PG          236
# TV-Y7       129
# TV-14        79
# PG-13        66
# TV-Y         49
# TV-Y7-FV     13
# TV-MA         3
# Name: rating, dtype: int64

# %%
df['duration'].value_counts()
# Out:
# 1 Season     219
# 2 Seasons     81
# 3 Seasons     43
# 44 min        42
# 7 min         42
#             ...
# 120 min        1
# 56 min         1
# 19 min         1
# 30 min         1
# 68 min         1
# Name: duration, Length: 158, dtype: int64

# %%
df['listed_in'].value_counts()
# Out:
# Animation, Comedy, Family                        124
# Action-Adventure, Animation, Comedy               77
# Action-Adventure, Animation, Kids                 45
# Animals & Nature, Documentary, Family             40
# Action-Adventure, Animation, Family               40
#                                                 ...
# Docuseries, Kids                                   1
# Animals & Nature, Family, Reality                  1
# Dance, Music, Musical                              1
# Comedy, Family, Lifestyle                          1
# Action-Adventure, Animals & Nature, Animation      1
# Name: listed_in, Length: 329, dtype: int64

# %%
df['release_year'].value_counts()
# Out:
# 2021    125
# 2020    114
# 2019     99
# 2017     69
# 2018     65
#        ...
# 1928      1
# 1944      1
# 1970      1
# 1945      1
# 1968      1
# Name: release_year, Length: 90, dtype: int64

# %%
df.head()
# Out:
#       type                                             title        country  \
# 0    Movie  Duck the Halls: A Mickey Mouse Christmas Special  United States
# 1    Movie                            Ernest Saves Christmas  United States
# 2    Movie                      Ice Age: A Mammoth Christmas  United States
# 3    Movie                        The Queen Family Singalong  United States
# 4  TV Show                             The Beatles: Get Back  United States
#
#   date_added  release_year rating  duration                      listed_in  \
# 0 2021-11-26          2016   TV-G    23 min              Animation, Family
# 1 2021-11-26          1988     PG    91 min                         Comedy
# 2 2021-11-26          2011   TV-G    23 min      Animation, Comedy, Family
# 3 2021-11-26          2021  TV-PG    41 min                        Musical
# 4 2021-11-25          2021  TV-MA  1 Season  Docuseries, Historical, Music
#
#    year_added  month_added  day_added
# 0        2021           11         26
# 1        2021           11         26
# 2        2021           11         26
# 3        2021           11         26
# 4        2021           11         25

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df.sample(10)
# Out:
#          type                                          title        country  \
# 762     Movie                                      Breaking2  United States
# 475     Movie          Hamilton: History Has Its Eyes on You  United States
# 530     Movie  Star Wars: The Rise of Skywalker (Episode IX)  United States
# 685     Movie                 Marvel Studios' Thor: Ragnarok  United States
# 1321    Movie                      The Princess and the Frog  United States
# 514   TV Show                                     The Greeks  United States
# 1393    Movie                                 Twas the Night  United States
# 1386    Movie                          Treasure of Matecumbe  United States
# 908     Movie                                  Geek Charming  United States
# 807     Movie       Davy Crockett, King of the Wild Frontier  United States
#
#      date_added  release_year rating  duration  \
# 762  2019-11-12          2017  TV-PG    55 min
# 475  2020-07-10          2020  TV-PG    47 min
# 530  2020-05-04          2019  PG-13   142 min
# 685  2019-12-05          2017  PG-13   132 min
# 1321 2019-11-12          2009      G    99 min
# 514  2020-06-05          2016  TV-PG  1 Season
# 1393 2019-11-12          2001   TV-G    87 min
# 1386 2019-11-12          1976      G   116 min
# 908  2019-11-12          2011   TV-G    99 min
# 807  2019-11-12          1955     PG    93 min
#
#                                       listed_in  year_added  month_added  \
# 762                         Documentary, Sports        2019           11
# 475                         Historical, Musical        2020            7
# 530   Action-Adventure, Family, Science Fiction        2020            5
# 685           Action-Adventure, Comedy, Fantasy        2019           12
# 1321                  Animation, Comedy, Family        2019           11
# 514                      Docuseries, Historical        2020            6
# 1393                     Comedy, Crime, Fantasy        2019           11
# 1386          Action-Adventure, Family, Mystery        2019           11
# 908                Comedy, Coming of Age, Drama        2019           11
# 807        Action-Adventure, Family, Historical        2019           11
#
#       day_added
# 762          12
# 475          10
# 530           4
# 685           5
# 1321         12
# 514           5
# 1393         12
# 1386         12
# 908          12
# 807          12

# %%
df_movie = df[df['type'] == 'Movie']

df_tv_show = df[df['type'] == 'TV Show']

# %%
# 10 country that give highest movies

df_movie[['type','country']].groupby(['country']).count()['type'].nlargest(10).to_frame()
# Out:
#                                           type
# country
# United States                              883
# United States, Canada                       25
# United States, United Kingdom               20
# Canada, United States                       16
# United Kingdom, United States               13
# United Kingdom                              11
# United States, Australia                     8
# United States, France                        4
# United States, United Kingdom, Australia     4
# Australia, United States                     3

# %%
# 10 country that give highest TV Show

df_tv_show[['type','country']].groupby(['country']).count()['type'].nlargest(10).to_frame()
# Out:
#                                type
# country
# United States                   339
# United Kingdom                   12
# United States, Canada             5
# United States, South Korea        3
# Argentina                         2
# Canada                            2
# United States, United Kingdom     2
# Argentina, Mexico                 1
# Australia, United Kingdom         1
# Canada, United States             1

# %%
# 10 highest duration for movies

df_movie[['type','duration']].groupby(['duration']).count()['type'].nlargest(10).to_frame()
# Out:
#           type
# duration
# 44 min      42
# 7 min       42
# 8 min       41
# 9 min       33
# 45 min      31
# 94 min      28
# 90 min      27
# 93 min      27
# 88 min      26
# 89 min      24

# %%
# 10 highest duration for TV Show

df_tv_show[['type','duration']].groupby(['duration']).count()['type'].nlargest(10).to_frame()
# Out:
#             type
# duration
# 1 Season     219
# 2 Seasons     81
# 3 Seasons     43
# 4 Seasons     24
# 5 Seasons     11
# 7 Seasons      5
# 6 Seasons      3
# 10 Seasons     2
# 8 Seasons      2
# 9 Seasons      2

# %%
# 10 highest rating for movies

df_movie[['type','rating']].groupby(['rating']).count()['type'].nlargest(10).to_frame()
# Out:
#           type
# rating
# G          253
# PG         235
# TV-G       233
# TV-PG      181
# PG-13       66
# TV-14       37
# TV-Y7       36
# TV-Y7-FV     7
# TV-Y         3
# TV-MA        1

# %%
# 10 highest rating for TV Show

df_tv_show[['type','rating']].groupby(['rating']).count()['type'].nlargest(10).to_frame()
# Out:
#           type
# rating
# TV-PG      120
# TV-Y7       93
# TV-G        85
# TV-Y        46
# TV-14       42
# TV-Y7-FV     6
# TV-MA        2
# PG           1

# %%
# 10 highest listed-in for movies

df_movie[['type','listed_in']].groupby(['listed_in']).count()['type'].nlargest(10).to_frame()
# Out:
#                                        type
# listed_in
# Animation, Comedy, Family               119
# Action-Adventure, Animation, Comedy      44
# Action-Adventure, Animation, Family      40
# Animals & Nature, Documentary, Family    40
# Animals & Nature, Documentary            35
# Animation, Family, Fantasy               31
# Action-Adventure, Comedy, Family         28
# Animation, Family                        25
# Documentary                              25
# Documentary, Historical                  21

# %%
# 10 highest listed-in for TV Show

df_tv_show[['type','listed_in']].groupby(['listed_in']).count()['type'].nlargest(10).to_frame()
# Out:
#                                                 type
# listed_in
# Action-Adventure, Animation, Kids                 39
# Animals & Nature, Docuseries, Family              39
# Action-Adventure, Animation, Comedy               33
# Animation, Kids                                   15
# Action-Adventure, Animation, Fantasy              12
# Action-Adventure, Animals & Nature, Docuseries    10
# Animals & Nature, Docuseries                      10
# Docuseries, Historical                            10
# Comedy, Coming of Age, Family                      8
# Comedy, Coming of Age, Kids                        7

# %%
# 10 highest Year for Added movies on Netflix

df_movie[['type','year_added']].groupby(['year_added']).count()['type'].nlargest(10).to_frame()
# Out:
#             type
# year_added
# 2019         630
# 2020         230
# 2021         192

# %%
# 10 highest Year for Added TV Show on Netflix

df_tv_show[['type','year_added']].groupby(['year_added']).count()['type'].nlargest(10).to_frame()
# Out:
#             type
# year_added
# 2021         138
# 2019         135
# 2020         122

# %%
# 10 highest Year release for movies on Netflix

df_movie[['type','release_year']].groupby(['release_year']).count()['type'].nlargest(10).to_frame()
# Out:
#               type
# release_year
# 2020            74
# 2021            70
# 2019            61
# 2011            35
# 2014            34
# 2017            33
# 2009            32
# 2018            32
# 2010            30
# 2016            30

# %%
# 10 highest Year release for TV Show on Netflix

df_tv_show[['type','release_year']].groupby(['release_year']).count()['type'].nlargest(10).to_frame()
# Out:
#               type
# release_year
# 2021            55
# 2020            40
# 2019            38
# 2017            36
# 2018            33
# 2016            30
# 2015            23
# 2011            17
# 2014            15
# 2012            12
